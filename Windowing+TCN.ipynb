# %% [markdown]
# ## Import Libraries

# %%
import os
import h5py
import numpy as np
import pandas as pd
from pandas import DataFrame
#import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %% [markdown]
# ## Loading Data

# %%
# Load data
def load_part_array (sample_dir_path, unit_num, win_len, stride, part_num):
    filename =  'Unit%s_win%s_str%s_part%s.npz' %(str(int(unit_num)), win_len, stride, part_num)
    filepath =  os.path.join(sample_dir_path, filename)
    loaded = np.load(filepath)
    return loaded['sample'], loaded['label']

def load_part_array_merge (npz_units):
    sample_array_lst = []
    label_array_lst = []
    for npz_unit in npz_units:
      loaded = np.load(npz_unit)
      sample_array_lst.append(loaded['sample'])
      label_array_lst.append(loaded['label'])
    sample_array = np.dstack(sample_array_lst)
    label_array = np.concatenate(label_array_lst)
    sample_array = sample_array.transpose(2, 0, 1)
    return sample_array, label_array

def load_array (sample_dir_path, unit_num, win_len, stride):
    filename =  'Unit%s_win%s_str%s_smp10.npz' %(str(int(unit_num)), win_len, stride)
    filepath =  os.path.join(sample_dir_path, filename)
    loaded = np.load(filepath)

    return loaded['sample'].transpose(2, 0, 1), loaded['label']

# %% [markdown]
# ### Choosing Specific Unitis for Training and Testing

# %%
def release_list(a):
   del a[:]
   del a

units_index_train = [16.0, 18.0, 20.0]
units_index_test = [11.0, 14.0, 15.0]

sample_dir_path ='Samples_whole'
sub=10

train_units_samples_lst =[]
train_units_labels_lst = []

for index in units_index_train:
        print("Load data index: ", index)
        sample_array, label_array = load_array (sample_dir_path, index, 50, 1)
        #sample_array, label_array = shuffle_array(sample_array, label_array)
        print("sample_array.shape", sample_array.shape)
        print("label_array.shape", label_array.shape)
        sample_array = sample_array[::sub]
        label_array = label_array[::sub]
        print("sub sample_array.shape", sample_array.shape)
        print("sub label_array.shape", label_array.shape)
        train_units_samples_lst.append(sample_array)
        train_units_labels_lst.append(label_array)
        
sample_array = np.concatenate(train_units_samples_lst)
label_array = np.concatenate(train_units_labels_lst)
print ("samples are aggregated")

release_list(train_units_samples_lst)
release_list(train_units_labels_lst)
train_units_samples_lst =[]
train_units_labels_lst = []
print("Memory released")

    #sample_array, label_array = shuffle_array(sample_array, label_array)
print("samples are shuffled")
print("sample_array.shape", sample_array.shape)
print("label_array.shape", label_array.shape)

print ("train sample dtype", sample_array.dtype)
print("train label dtype", label_array.dtype)
# Out:
# Load data index:  16.0
# sample_array.shape (76480, 50, 20)
# label_array.shape (76480,)
# sub sample_array.shape (7648, 50, 20)
# sub label_array.shape (7648,)
# Load data index:  18.0
# sample_array.shape (89023, 50, 20)
# label_array.shape (89023,)
# sub sample_array.shape (8903, 50, 20)
# sub label_array.shape (8903,)
# Load data index:  20.0
# sample_array.shape (76767, 50, 20)
# label_array.shape (76767,)
# sub sample_array.shape (7677, 50, 20)
# sub label_array.shape (7677,)
# samples are aggregated
# Memory released
# samples are shuffled
# sample_array.shape (24228, 50, 20)
# label_array.shape (24228,)
# train sample dtype float32
# train label dtype float32

# %% [markdown]
# ### Temporal Convolutional Network

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Embedding
from tensorflow.keras.layers import BatchNormalization, Activation, LSTM, TimeDistributed, Bidirectional
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.initializers import GlorotNormal, GlorotUniform
from tensorflow.keras.initializers import GlorotNormal, GlorotUniform
from tcn import TCN

tcn_layer = TCN(input_shape=(sample_array.shape[1], sample_array.shape[2]))

model = Sequential()
model.add(tf.keras.layers.Input(shape=(sample_array.shape[1],sample_array.shape[2]), name="input"))
model.add(TCN(
    nb_filters=5,
    kernel_size=3,
   
))
model.add(tf.keras.layers.Dense(100, activation='relu', name="Dense_1"))
model.add(tf.keras.layers.Dense(1, activation='linear', name="Dense_2"))


model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])
print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_13 (TCN)                 (None, 5)                 1290
# _________________________________________________________________
# Dense_1 (Dense)              (None, 100)               600
# _________________________________________________________________
# Dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 1,991
# Trainable params: 1,991
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(
    sample_array,
    label_array,
    validation_split=0.1,
    epochs=250,
    batch_size=512,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/250
# 43/43 [==============================] - 2s 20ms/step - loss: 899.2982 - mean_squared_error: 899.2982 - val_loss: 712.8006 - val_mean_squared_error: 712.8006
# Epoch 2/250
# 43/43 [==============================] - 0s 11ms/step - loss: 404.0399 - mean_squared_error: 404.0399 - val_loss: 770.7092 - val_mean_squared_error: 770.7092
# Epoch 3/250
# 43/43 [==============================] - 0s 11ms/step - loss: 377.9859 - mean_squared_error: 377.9859 - val_loss: 749.7096 - val_mean_squared_error: 749.7096
# Epoch 4/250
# 43/43 [==============================] - 0s 11ms/step - loss: 369.8277 - mean_squared_error: 369.8277 - val_loss: 729.6608 - val_mean_squared_error: 729.6608
# Epoch 5/250
# 43/43 [==============================] - 0s 11ms/step - loss: 347.7474 - mean_squared_error: 347.7474 - val_loss: 607.6041 - val_mean_squared_error: 607.6041
# Epoch 6/250
# 43/43 [==============================] - 0s 11ms/step - loss: 294.9331 - mean_squared_error: 294.9331 - val_loss: 428.5507 - val_mean_squared_error: 428.5507
# Epoch 7/250
# 43/43 [==============================] - 1s 12ms/step - loss: 209.3364 - mean_squared_error: 209.3364 - val_loss: 208.4780 - val_mean_squared_error: 208.4780
# Epoch 8/250
# 43/43 [==============================] - 0s 11ms/step - loss: 135.9268 - mean_squared_error: 135.9268 - val_loss: 118.4719 - val_mean_squared_error: 118.4719
# Epoch 9/250
# 43/43 [==============================] - 0s 11ms/step - loss: 102.3376 - mean_squared_error: 102.3376 - val_loss: 80.4949 - val_mean_squared_error: 80.4949
# Epoch 10/250
# 43/43 [==============================] - 0s 11ms/step - loss: 78.3617 - mean_squared_error: 78.3617 - val_loss: 51.0704 - val_mean_squared_error: 51.0704
# Epoch 11/250
# 43/43 [==============================] - 0s 11ms/step - loss: 60.5328 - mean_squared_error: 60.5328 - val_loss: 33.8636 - val_mean_squared_error: 33.8636
# Epoch 12/250
# 43/43 [==============================] - 0s 11ms/step - loss: 46.1516 - mean_squared_error: 46.1516 - val_loss: 17.1737 - val_mean_squared_error: 17.1737
250
# 43/43 [==============================] - 0s 11ms/step - loss: 25.0180 - mean_squared_error: 25.0180 - val_loss: 4.6998 - val_mean_squared_error: 4.6998
# Epoch 33/250
# 43/43 [==============================] - 0s 12ms/step - loss: 25.0285 - mean_squared_error: 25.0285 - val_loss: 4.3042 - val_mean_squared_error: 4.3042
# Epoch 34/250
# 43/43 [==============================] - 0s 11ms/step - loss: 24.6892 - mean_squared_error: 24.6892 - val_loss: 4.0812 - val_mean_squared_error: 4.0812
# Epoch 35/250
# 43/43 [==============================] - 0s 11ms/step - loss: 25.2440 - mean_squared_error: 25.2440 - val_loss: 5.0635 - val_mean_squared_error: 5.0635
# Epoch 36/250
# 43/43 [==============================] - 0s 11ms/step - loss: 25.5265 - mean_squared_error: 25.5265 - val_loss: 3.9485 - val_mean_squared_error: 3.9485
# Epoch 37/250
# 43/43 [==============================] - 0s 11ms/step - loss: 25.3583 - mean_squared_error: 25.3583 - val_loss: 5.6466 - val_mean_squared_error: 5.6466
# Epoch 38/250
# 43/43 [==============================] - 0s 11ms/step - loss: 24.0797 - mean_squared_error: 24.0797 - val_loss: 3.6089 - val_mean_squared_error: 3.6089
# Epoch 39/250
# 43/43 [==============================] - 1s 12ms/step - loss: 24.7967 - mean_squared_error: 24.7967 - val_loss: 4.9762 - val_mean_squared_error: 4.9762
# Epoch 40/250
# 43/43 [==============================] - 0s 11ms/step - loss: 23.7930 - mean_squared_error: 23.7930 - val_loss: 3.6951 - val_mean_squared_error: 3.6951
# Epoch 41/250
# 43/43 [==============================] - 0s 11ms/step - loss: 25.8212 - mean_squared_error: 25.8212 - val_loss: 3.8482 - val_mean_squared_error: 3.8482
# Epoch 42/250
# 43/43 [==============================] - 0s 11ms/step - loss: 23.8579 - mean_squared_error: 23.8579 - val_loss: 4.7628 - val_mean_squared_error: 4.7628
# Epoch 43/250
# 43/43 [==============================] - 0s 11ms/step - loss: 23.6849 - mean_squared_error: 23.6849 - val_loss: 4.1511 - val_mean_squared_error: 4.1511
# Epoch 44/250
# 43/43 [==============================] - 0s 11ms/step - loss: 24.2874 - mean_squared_error: 24.2874 - val_loss: 5.1255 - val_mean_squared_error: 5.1255
# Epoch 45/250
# 43/43 [==============================] - 0s 12ms/step - loss: 23.3441 - mean_squared_error: 23.3441 - val_loss: 3.6542 - val_mean_squared_error: 3.6542
# Epoch 46/250
# 43/43 [==============================] - 0s 11ms/step - loss: 24.1280 - mean_squared_error: 24.1280 - val_loss: 3.3691 - val_mean_squared_error: 3.3691
# Epoch 47/250
# 43/43 [==============================] - 0s 11ms/step - loss: 25.5820 - mean_squared_error: 25.5820 - val_loss: 3.7229 - val_mean_squared_error: 3.7229
# Epoch 48/250
# 43/43 [==============================] - 0s 11ms/step - loss: 24.4875 - mean_squared_error: 24.4875 - val_loss: 3.5744 - val_mean_squared_error: 3.5744
# Epoch 49/250
# 43/43 [==============================] - 0s 11ms/step - loss: 23.2536 - mean_squared_error: 23.2536 - val_loss: 3.4732 - val_mean_squared_error: 3.4732
# Epoch 50/250
# 43/43 [==============================] - 0s 11ms/step - loss: 23.1273 - mean_squared_error: 23.1273 - val_loss: 2.6444 - val_mean_squared_error: 2.6444
# Epoch 51/250
# 43/43 [==============================] - 0s 11ms/step - loss: 25.0060 - mean_squared_error: 25.0060 - val_loss: 3.6097 - val_mean_squared_error: 3.6097
# Epoch 52/250
# 43/43 [==============================] - 0s 11ms/step - loss: 21.9944 - mean_squared_error: 21.9944 - val_loss: 4.4972 - val_mean_squared_error: 4.4972
# Epoch 53/250
# 43/43 [==============================] - 0s 12ms/step - loss: 23.3201 - mean_squared_error: 23.3201 - val_loss: 4.3804 - val_mean_squared_error: 4.3804
# Epoch 54/250
# 43/43 [==============================] - 0s 11ms/step - loss: 23.8179 - mean_squared_error: 23.8179 - val_loss: 2.5101 - val_mean_squared_error: 2.5101
# Epoch 55/250
# 43/43 [==============================] - 0s 11ms/step - loss: 23.6644 - mean_squared_error: 23.6644 - val_loss: 3.7982 - val_mean_squared_error: 3.7982
# Epoch 56/250
# 43/43 [==============================] - 0s 11ms/step - loss: 22.8026 - mean_squared_error: 22.8026 - val_loss: 2.5607 - val_mean_squared_error: 2.5607
# Epoch 57/250
# 43/43 [==============================] - 0s 11ms/step - loss: 24.0052 - mean_squared_error: 24.0052 - val_loss: 3.6325 - val_mean_squared_error: 3.6325
# Epoch 58/250
# 43/43 [==============================] - 0s 11ms/step - loss: 22.3627 - mean_squared_error: 22.3627 - val_loss: 3.7322 - val_mean_squared_error: 3.7322
# Epoch 59/250
# 43/43 [==============================] - 0s 11ms/step - loss: 22.4792 - mean_squared_error: 22.4792 - val_loss: 2.5457 - val_mean_squared_error: 2.5457
# Epoch 60/250
# 43/43 [==============================] - 0s 11ms/step - loss: 21.7846 - mean_squared_error: 21.7846 - val_loss: 2.2141 - val_mean_squared_error: 2.2141
# Epoch 61/250
# 43/43 [==============================] - 0s 11ms/step - loss: 21.9278 - mean_squared_error: 21.9278 - val_loss: 4.4298 - val_mean_squared_error: 4.4298
# Epoch 62/250
# 43/43 [==============================] - 0s 11ms/step - loss: 23.1485 - mean_squared_error: 23.1485 - val_loss: 2.5241 - val_mean_squared_error: 2.5241
# Epoch 63/250
# 43/43 [==============================] - 0s 11ms/step - loss: 22.7034 - mean_squared_error: 22.7034 - val_loss: 3.9983 - val_mean_squared_error: 3.9983
# Epoch 64/250
# 43/43 [==============================] - 0s 11ms/step - loss: 21.9453 - mean_squared_error: 21.9453 - val_loss: 2.9868 - val_mean_squared_error: 2.9868
# Epoch 65/250
# 43/43 [==============================] - 0s 11ms/step - loss: 22.7054 - mean_squared_error: 22.7054 - val_loss: 4.1903 - val_mean_squared_error: 4.1903
# Epoch 66/250
# 43/43 [==============================] - 0s 11ms/step - loss: 22.7053 - mean_squared_error: 22.7053 - val_loss: 5.0096 - val_mean_squared_error: 5.0096
# Epoch 67/250
# 43/43 [==============================] - 0s 12ms/step - loss: 22.3254 - mean_squared_error: 22.3254 - val_loss: 4.2663 - val_mean_squared_error: 4.2663
# Epoch 68/250
# 43/43 [==============================] - 0s 11ms/step - loss: 21.6033 - mean_squared_error: 21.6033 - val_loss: 2.8863 - val_mean_squared_error: 2.8863
# Epoch 69/250
# 43/43 [==============================] - 0s 12ms/step - loss: 20.7786 - mean_squared_error: 20.7786 - val_loss: 3.8954 - val_mean_squared_error: 3.8954
# Epoch 70/250
# 43/43 [==============================] - 0s 11ms/step - loss: 21.0470 - mean_squared_error: 21.0470 - val_loss: 3.0647 - val_mean_squared_error: 3.0647

# %%
import matplotlib.pyplot as plt


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()


from math import sqrt
from sklearn.metrics import mean_squared_error

output_lst = []
truth_lst = []   

for index in units_index_test:
        sample_array, label_array = load_array(sample_dir_path, index, 50, 1)
        sample_array = sample_array[::sub]
        label_array = label_array[::sub]

        y_pred_test = model.predict(sample_array)
        output_lst.append(y_pred_test)
        truth_lst.append(label_array)

output_array = np.concatenate(output_lst)[:, 0]
trytg_array = np.concatenate(truth_lst)

RMSE = sqrt(mean_squared_error(output_array, trytg_array))
print(RMSE)
# Out:
# 5.263598134049793

# %%
model.save('WindowingTCN.h5')
